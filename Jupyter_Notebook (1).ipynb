# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Raushan Zhandayeva**
# <br> PhD student

# %% [markdown]
# *I am interested in data science because it is a multidisciplinary field that can
# help uncover a lot of insights to the most urgent and important questions.*

# %% [markdown]
# ### My code in Cell 5 is supposed to show a list of animals

# %%
x = ["dogs", "cats", "rabbits", "hamsters"]
print(x)
# Out:
# ['dogs', 'cats', 'rabbits', 'hamsters']

# %% [markdown]
# - Animals
#     - Dogs
#     - Cats
#     - Rabbits
#     - Hamsters
#
# ***
# __[Dog](https://en.wikipedia.org/wiki/Dog)__
# <br>__[Cat](https://en.wikipedia.org/wiki/Cat)__
# <br>__[Rabbit](https://en.wikipedia.org/wiki/Rabbit)__
# <br>__[Hamster](https://en.wikipedia.org/wiki/Hamster)__
#
# ***
# ![licensed-image (1).jpeg](attachment:a1dbbad5-8d4e-4bff-8028-96f79374ba9a.jpeg)
# ***
# ![3683.webp](attachment:92b4c33e-2cac-4b62-a1a8-e6be7c66be12.webp)
# ***
# ![petrabbitcare-1-scaled.jpg](attachment:37ca0cfb-e209-44a2-b6eb-5595bd9e0a76.jpg)
# ***
# ![licensed-image.jpeg](attachment:e1b60f56-49f2-4459-af84-fa7f40e61b9e.jpeg)
